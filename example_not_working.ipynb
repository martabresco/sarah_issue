# %%
import xarray as xr
import matplotlib.pyplot as plt
import cartopy.crs as ccrs
import cartopy.feature as cfeature
import atlite
import numpy as np
import logging 
logging.basicConfig(level=logging.INFO)

# %%
#change the path to the file. File is also in the github repository
ds_sarah=xr.open_dataset("C:/Users/marta/Desktop/Thesis/Climate-Change-Impacted-Solar-Energy-Generation/sarah_20110301_20110331/SIDin201103010000004UD1000101UD.nc")
ds_sarah
# Out:
# <xarray.Dataset> Size: 81MB
# Dimensions:        (time: 48, lon: 600, bnds: 2, lat: 700)
# Coordinates:
#   * time           (time) datetime64[ns] 384B 2011-03-01 ... 2011-03-01T23:30:00
#   * lon            (lon) float32 2kB -9.975 -9.925 -9.875 ... 19.88 19.92 19.98
#   * lat            (lat) float32 3kB 30.02 30.08 30.12 ... 64.88 64.93 64.97
# Dimensions without coordinates: bnds
# Data variables:
#     lon_bnds       (lon, bnds) float32 5kB ...
#     lat_bnds       (lat, bnds) float32 6kB ...
#     SID            (time, lat, lon) float32 81MB ...
#     record_status  (time) int8 48B ...
# Attributes: (12/41)
#     CDI:                        Climate Data Interface version 2.4.0 (https:/...
#     Conventions:                CF-1.7,ACDD-1.3
#     institution:                EUMETSAT/CMSAF
#     id:                         DOI:10.5676/EUM_SAF_CM/SARAH/V003
#     product_version:            3.0
#     creator_name:               DE/DWD
#     ...                         ...
# ...

# %%
start_date="2011-03-01"
end_date="2011-03-31"
cutout = atlite.Cutout(
    path="europe_201103",
    module=["sarah", "era5"],
    sarah_dir="C:/Users/Marta/Desktop/Thesis/Climate-Change-Impacted-Solar-Energy-Generation/sarah_20110301_20110331", #change directory
    x=slice(-9.975, 19.98),
    y=slice(30, 65),
    time=slice(start_date, end_date),
    chunks={"time": 100},
)
# Out:
# INFO:atlite.cutout:Building new cutout europe_201103.nc

# %%
cutout.prepare()
# Out:
# INFO:atlite.data:Storing temporary files in C:\Users\marta\AppData\Local\Temp\tmpti62p50n
# INFO:atlite.data:Calculating and writing with module sarah:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[13], line 1
# ----> 1 cutout.prepare()
#
# File c:\Users\marta\anaconda3\envs\atlite_cmip6_2025\Lib\site-packages\atlite\data.py:115, in maybe_remove_tmpdir.<locals>.wrapper(*args, **kwargs)
#     113 kwargs["tmpdir"] = mkdtemp()
#     114 try:
# --> 115     res = func(*args, **kwargs)
#     116 finally:
#     117     rmtree(kwargs["tmpdir"])
#
# File c:\Users\marta\anaconda3\envs\atlite_cmip6_2025\Lib\site-packages\atlite\data.py:208, in cutout_prepare(cutout, features, tmpdir, overwrite, compression, show_progress, dask_kwargs, monthly_requests, concurrent_requests)
#     206 logger.info(f"Calculating and writing with module {module}:")
# ...
